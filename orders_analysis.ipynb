# %%
#import librarbies
# !pip install kaggle
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import os
os.makedirs(r'C:\Users\{}'.format(os.getenv('USERNAME')) + r'\.kaggle', exist_ok=True)
print("Folder created at:", r'C:\Users\{}'.format(os.getenv('USERNAME')) + r'\.kaggle')
# Out:
# Folder created at: C:\Users\DELL\.kaggle

# %%
import kaggle
kaggle.api.authenticate()
print("Authenticated successfully!")

# Now download the dataset
kaggle.api.dataset_download_files(
    'ankitbansal06/retail-orders',
    path='.',
    unzip=True
)
print("Dataset downloaded!")
# Out:
# Authenticated successfully!
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# Dataset downloaded!

# %%
import os
print(os.getenv('USERNAME'))
# Out:
# DELL

# %%
import os
r'C:\\Users\\YOUR_USERNAME\\.kaggle\\kaggle.json'
print("File found:", os.path.exists(path))
# Out:
# File found: True

# %%
import kaggle
kaggle.api.authenticate()
print("Authenticated!")

kaggle.api.dataset_download_files(
    'ankitbansal06/retail-orders',
    path='.',
    unzip=True
)
print("orders.csv downloaded!")
# Out:
# Authenticated!
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# orders.csv downloaded!

# %%
#read data from the file and handle null values
import pandas as pd
df = pd.read_csv('orders.csv',na_values=['Not Available', 'unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#renamed column names and make them lower case and replaced space with underscore
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#created new columns discount, sale price and profit
df['discount'] = df['list_price']*df['discount_percent']*.01
df['sale_price'] = df['list_price']-df['discount']
df['profit'] = df['sale_price']-df['cost_price']
df.head(5)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#coverted order date from object data type to datetime
df['order_date'] = pd.to_datetime(df['order_date'],format="%Y-%m-%d")

# %%
#drop cost price, list price and discount percentage columns
df.drop(columns=['list_price', 'cost_price','discount_percent'],inplace=True)

# %%
df.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  quantity  discount  sale_price  profit
# 0    Bookcases  FUR-BO-10001798         2       5.2       254.8    14.8
# ...

# %%
#loading the data into SQL Server using replace option
import sqlalchemy as sql
engine = sql.create_engine("mssql+pyodbc://MOHIT-DESKTOP/OrdersAnalysisProject?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# Test the connection
with engine.connect() as conn:
    print("Connect Successfully")
# Out:
# Connect Successfully

# %%
#loading the data into SQL Server using append option
df.to_sql('df_orders', con=engine, index=False, if_exists = 'append')
print("Data loaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2118, in Connection._exec_insertmany_context(self, dialect, context)
#    2117     else:
# -> 2118         dialect.do_execute(
#    2119             cursor,
#    2120             sub_stmt,
#    2121             sub_params,
#    2122             context,
#    2123         )
#    2125 except BaseException as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# ...
